# %% [markdown]
# <a href="https://colab.research.google.com/github/lokeshpuma/ML_projects/blob/main/chatbot_with_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from transformers import AutoTokenizer, pipeline, AutoModelForCausalLM

get_ipython().config['IPKernelApp']['parent_appname'] = ''

import warnings
warnings.filterwarnings('ignore')

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "microsoft/DialoGPT-medium"
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(model_name)

text_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)

print("Model loaded successfully!")
# Out:
# tokenizer_config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/863M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/863M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Device set to use cuda:0
# Model loaded successfully!

# %%
from google.colab import userdata
import google.generativeai as genai

api_key = userdata.get('GEMINI_API_KEY')
genai.configure(api_key=api_key)

model = genai.GenerativeModel('gemini-2.5-flash')

print("Chat with puma! (Type 'quit' to exit)\n")

chat = model.start_chat(history=[])

while True:
    user_input = input("lokesh: ")

    if user_input.lower() in ['quit', 'exit', 'stop']:
        print("Chat ended!")
        break

    response = chat.send_message(user_input)
    print(f"puma: {response.text}\n")
# Out:
# Chat with puma! (Type 'quit' to exit)
#
# lokesh: what is data science
# puma: Data science is an **interdisciplinary field** that uses **scientific methods, processes, algorithms, and systems** to extract knowledge and insights from structured and unstructured data. Its primary goal is to **turn raw data into understanding and actionable intelligence** that can be used for decision-making and problem-solving.
#
# Think of it as the art and science of "making sense" of vast amounts of information.
#
# Here's a breakdown of what that entails:
#
# 1.  **Interdisciplinary Nature:** Data science combines elements from several fields:
#     *   **Mathematics & Statistics:** For understanding data distributions, probability, hypothesis testing, and model evaluation.
#     *   **Computer Science & Programming:** For data collection, storage, processing, algorithm implementation, and building scalable systems.
# ...
