# %% [markdown]
# <a href="https://colab.research.google.com/github/lokeshpuma/ML_projects/blob/main/chatbot_with_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from transformers import AutoTokenizer, pipeline, AutoModelForCausalLM

get_ipython().config['IPKernelApp']['parent_appname'] = ''

import warnings
warnings.filterwarnings('ignore')

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "microsoft/DialoGPT-medium"
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(model_name)

text_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)

print("Model loaded successfully!")
# Out:
# Device set to use cuda:0
# Model loaded successfully!

# %%
from google.colab import userdata
import google.generativeai as genai

api_key = userdata.get('GEMINI_API_KEY')
genai.configure(api_key=api_key)

model = genai.GenerativeModel('gemini-2.5-flash')

print("Chat with puma! (Type 'quit' to exit)\n")

chat = model.start_chat(history=[])

while True:
    user_input = input("lokesh: ")

    if user_input.lower() in ['quit', 'exit', 'stop']:
        print("Chat ended!")
        break

    response = chat.send_message(user_input)
    print(f"puma: {response.text}\n")
# Out:
# Chat with puma! (Type 'quit' to exit)
#
# lokesh: what is time
# puma: "What is time?" is one of the most profound and challenging questions in both philosophy and physics. There isn't one single, universally agreed-upon definition, but rather multiple layers of understanding.
#
# Here's a breakdown of different perspectives:
#
# 1.  **The Everyday/Intuitive Understanding:**
#     *   **Sequence of Events:** Time is how we order events, from past to present to future. It's the dimension that allows us to distinguish between what happened, what is happening, and what will happen.
#     *   **Measurement of Duration:** It's what clocks measure – how long something lasts, or the interval between two events. We use units like seconds, minutes, hours, days, years.
#     *   **Flow/Progression:** We experience time as a continuous, irreversible flow, always moving forward.
#     *   **Associated with Change:** If nothing ever changed, would we perceive time? Time is inherently linked to processes, motion, and transformation.
#
# 2.  **The Scientific Perspective (Physics):**
#
#     *   **Classical Physics (Newtonian Time):** Isaac Newton conceived of time as "absolute, true, and mathematical time, of itself, and from its own nature, flows equably without relation to anything external." In this view, time is a universal, unchanging background against which all events unfold, independent of observers or events. It's like a steady, invisible river flowing everywhere at the same rate.
#
#     *   **Relativity (Einstein's Revolution):** Albert Einstein shattered the Newtonian view with his theories of Special and General Relativity.
#         *   **Spacetime:** Einstein showed that time is not separate from space, but is intricately woven into a four-dimensional fabric called **spacetime**.
#         *   **Relativity of Time:** Time is not absolute; its passage is relative to the observer's motion and the strength of the gravitational field.
#             *   **Time Dilation:** Clocks run slower for observers who are moving at higher speeds relative to another observer (Special Relativity).
#             *   **Gravitational Time Dilation:** Clocks run slower in stronger gravitational fields (General Relativity).
#         *   **No Universal "Now":** Because time is relative, there is no single, universal "now" that applies to everyone in the universe. Different observers can have different "nows."
#
#     *   **Thermodynamics (The Arrow of Time):** The Second Law of Thermodynamics introduces the concept of entropy (disorder). It states that the total entropy of an isolated system can only increase over time, or remain constant. This provides a direction for time, explaining why time only seems to move forward and why we remember the past but not the future. It's a one-way street of increasing disorder.
#
#     *   **Quantum Physics & Cosmology:**
#         *   At the quantum level, the concept of time becomes even more complex and potentially breaks down or emerges from other phenomena. Some theories of quantum gravity suggest that time might not be a fundamental property of the universe at its most basic level, but rather an emergent phenomenon.
#         *   Cosmology ties the origin of time to the Big Bang – if the universe had a beginning, then perhaps time itself also had a beginning.
#
# 3.  **The Philosophical Perspective:**
#
#     *   **Subjectivity:** Our perception of time can be subjective. Time "flies" when we're enjoying ourselves and "drags" when we're bored or waiting.
#     *   **Existence:** Is time a fundamental feature of reality, existing independently of human consciousness, or is it a construct of the human mind, a tool we use to organize our experiences?
#     *   **Presentism vs. Eternalism:**
#         *   **Presentism:** Only the present moment is real; the past is gone, the future does not yet exist.
#         *   **Eternalism (Block Universe):** The past, present, and future all exist simultaneously in a four-dimensional "block" of spacetime. Our experience of "now" is just a slice through this block. This view is often favored by physicists due to the implications of relativity.
#     *   **St. Augustine's Insight:** "What then is time? If no one asks me, I know; if I wish to explain it to one who asks, I know not." This famous quote perfectly captures the elusive nature of time – it's something we instinctively understand and live by, yet struggle to define definitively.
#
# **In Summary:**
#
# Time is simultaneously:
# *   A **dimension** that orders events and allows for change.
# *   A **measurement** of duration and sequence.
# *   A **relative phenomenon** influenced by gravity and motion.
# *   An **arrow** pointing towards increasing entropy.
# *   A profound **mystery** that continues to challenge our understanding of reality.
#
# It's one of the most fundamental and yet least understood aspects of our universe and our existence within it.
#
# lokesh: exit
# Chat ended!
